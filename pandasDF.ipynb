# %%
import pandas as pd

# %%
df = pd.DataFrame({'X' : [1,2,3,4,5], 'Y' : [2,3,4,5,6]})
df
# Out:
#    X  Y
# 0  1  2
# 1  2  3
# 2  3  4
# 3  4  5
# 4  5  6

# %%
print(df.info())
print('Shape', df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       5 non-null      int64
#  1   Y       5 non-null      int64
# dtypes: int64(2)
# memory usage: 212.0 bytes
# None
# Shape (5, 2)

# %%
survey_data = pd.read_csv('/Users/parag/Downloads/stack-overflow-developer-survey-2024/survey_results_public.csv')
print(survey_data.info())
print(survey_data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), object(100)
# memory usage: 56.9+ MB
# None
# (65437, 114)

# %%
pd.set_option('display.max_rows',100)
pd.set_option('display.max_columns',115)
print(survey_data.head(100))
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                     I am a developer by profession
# 1            2                     I am a developer by profession
# 2            3                     I am a developer by profession
# 3            4                              I am learning to code
# 4            5                     I am a developer by profession
# 5            6                        I code primarily as a hobby
# 6            7  I am not primarily a developer, but I write co...
# 7            8                              I am learning to code
# 8            9                        I code primarily as a hobby
# 9           10                     I am a developer by profession
# 10          11  I used to be a developer by profession, but no...
# 11          12                     I am a developer by profession
# 12          13                     I am a developer by profession
# ...

# %%
print(survey_data.columns)
print(survey_data.tail(100))
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)
#        ResponseId                                         MainBranch  \
# 65337       65338                              I am learning to code
# 65338       65339                              I am learning to code
# 65339       65340  I am not primarily a developer, but I write co...
# 65340       65341                     I am a developer by profession
# 65341       65342                              I am learning to code
# 65342       65343                     I am a developer by profession
# 65343       65344                     I am a developer by profession
# ...
